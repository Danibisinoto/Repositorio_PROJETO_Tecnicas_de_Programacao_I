# %%
import pandas as pd

# %%
#lendo o arquivo CSV
livros = pd.read_csv("Books_Data_Clean.csv")

#qtde de linhas e colunas do DataFrame
livros.shape
# Out:
# (1070, 15)

# %%
livros
# Out:
#       index  Publishing Year                        Book Name  \
# 0         0           1975.0                          Beowulf
# 1         1           1987.0                 Batman: Year One
# 2         2           2015.0                Go Set a Watchman
# 3         3           2008.0  When You Are Engulfed in Flames
# 4         4           2011.0         Daughter of Smoke & Bone
# ...     ...              ...                              ...
# 1065   1065           2014.0                    Gray Mountain
# 1066   1066           1989.0                 The Power of One
# 1067   1067           1930.0               The Maltese Falcon
# 1068   1068           2011.0                       Night Road
# 1069   1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# ...

# %%
#lendo as 10 primeiras linhas do DataFrame
livros.head(10)
# Out:
#    index  Publishing Year                                Book Name  \
# 0      0           1975.0                                  Beowulf
# 1      1           1987.0                         Batman: Year One
# 2      2           2015.0                        Go Set a Watchman
# 3      3           2008.0          When You Are Engulfed in Flames
# 4      4           2011.0                 Daughter of Smoke & Bone
# 5      5           2015.0                                Red Queen
# 6      6           2011.0                       The Power of Habit
# 7      7           1994.0  Midnight in the Garden of Good and Evil
# 8      8           2012.0                                 Hopeless
# 9      9           1905.0                        A Little Princess
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# ...

# %%
#lendo as 10 últimas linhas do DataFrame
livros.tail(10)
# Out:
#       index  Publishing Year  \
# 1060   1060           1972.0
# 1061   1061           1996.0
# 1062   1062           1982.0
# 1063   1063           2004.0
# 1064   1064           1994.0
# 1065   1065           2014.0
# 1066   1066           1989.0
# 1067   1067           1930.0
# 1068   1068           2011.0
# 1069   1069           1999.0
#
#                                               Book Name             Author  \
# 1060                                 The Farthest Shore  Ursula K. Le Guin
# 1061                                           Airframe   Michael Crichton
# 1062                                           Magician   Raymond E. Feist
# 1063                                             Bet Me    Jennifer Crusie
# 1064  Long Walk to Freedom: The Autobiography of Nel...     Nelson Mandela
# 1065                                      Gray Mountain       John Grisham
# 1066                                   The Power of One    Bryce Courtenay
# ...

# %%
#informações sobre o DataFrame, tipos de dados e valores não nulos
livros.info()

## >>> alguns valores nulos em Book Name, mas principalmente em language_code
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                1070 non-null   int64
#  1   Publishing Year      1069 non-null   float64
#  2   Book Name            1047 non-null   object
#  3   Author               1070 non-null   object
#  4   language_code        1017 non-null   object
#  5   Author_Rating        1070 non-null   object
#  6   Book_average_rating  1070 non-null   float64
#  7   Book_ratings_count   1070 non-null   int64
#  8   genre                1070 non-null   object
#  9   gross sales          1070 non-null   float64
#  10  publisher revenue    1070 non-null   float64
#  11  sale price           1070 non-null   float64
#  12  sales rank           1070 non-null   int64
#  13  Publisher            1070 non-null   object
#  14  units sold           1070 non-null   int64
# ...

# %%
#qtde de valores nulos por coluna

livros.isnull().sum()

## >>> confirma a análise anterior: qtde de valores nulos em Book Name, mas principalmente em language_code
# Out:
# index                   0
# Publishing Year         1
# Book Name              23
# Author                  0
# language_code          53
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# genre                   0
# gross sales             0
# publisher revenue       0
# sale price              0
# sales rank              0
# Publisher               0
# units sold              0
# dtype: int64

# %%
#percentual de nulos em comparação com o total de linhas do DataFrame

(livros.isnull().sum()/livros.shape[0])*100

## >> comparando com o DataFrame, o percentual de valores nulos em Book Name e language_code é baixo
# Out:
# index                  0.000000
# Publishing Year        0.093458
# Book Name              2.149533
# Author                 0.000000
# language_code          4.953271
# Author_Rating          0.000000
# Book_average_rating    0.000000
# Book_ratings_count     0.000000
# genre                  0.000000
# gross sales            0.000000
# publisher revenue      0.000000
# sale price             0.000000
# sales rank             0.000000
# Publisher              0.000000
# units sold             0.000000
# dtype: float64

# %%
livros1 = pd.read_csv("kindle_data-v2.csv")

# %%
livros1.shape
# Out:
# (133102, 16)

# %%
livros1
# Out:
#               asin                                              title  \
# 0       B00TZE87S4  Adult Children of Emotionally Immature Parents...
# 1       B08WCKY8MB  From Strength to Strength: Finding Success, Ha...
# 2       B09KPS84CJ  Good Inside: A Guide to Becoming the Parent Yo...
# 3       B07S7QPG6J             Everything I Know About Love: A Memoir
# 4       B00N6PEQV0  The Seven Principles for Making Marriage Work:...
# ...            ...                                                ...
# 133097  B0C3SJDLK8                                      Anna Karenina
# 133098  B09DW752Y1  Scary Smart: Scary Smart: The Future of Artifi...
# 133099  B0CFWHPJTN  The Count of Monte Cristo: The Original Unabri...
# 133100  B0C1KMFXJC                                      War And Peace
# 133101  B0BS1KYZB6                                Pride and Prejudice
#
#                    author                    soldBy  \
# 0       Lindsay C. Gibson   Amazon.com Services LLC
# ...
